# %%
from plotnine.data import economics # import the economics dataset

# %%
economics
# Out:
#           date      pce     pop  psavert  uempmed  unemploy
# 0   1967-07-01    507.4  198712     12.5      4.5      2944
# 1   1967-08-01    510.5  198911     12.5      4.7      2945
# 2   1967-09-01    516.3  199113     11.7      4.6      2958
# 3   1967-10-01    512.9  199311     12.5      4.9      3143
# 4   1967-11-01    518.1  199498     12.5      4.7      3066
# ..         ...      ...     ...      ...      ...       ...
# 569 2014-12-01  12122.0  320201      5.0     12.6      8688
# 570 2015-01-01  12080.8  320367      5.5     13.4      8979
# 571 2015-02-01  12095.9  320534      5.7     13.1      8705
# 572 2015-03-01  12161.5  320707      5.2     12.2      8575
# 573 2015-04-01  12158.9  320887      5.6     11.7      8549
#
# [574 rows x 6 columns]

# %%
from plotnine import ggplot, aes, geom_line # import the ggplot() class as well as some useful functions from plotnine, aes() and geom_line()
# A plot of population over time
(
    ggplot(economics) # What data to use
    + aes(x="date", y="pop") # What variable to use
    + geom_line() # Geometric object to use for drawing
)
# Out:
# <ggplot: (8769341665041)>

# %% [markdown]
# ## To Visualize the Data and make X,Y Plot

# %%
from plotnine.data import mpg

print(mpg)

from plotnine import ggplot, aes, geom_point, geom_boxplot, geom_map, geom_bar

print(ggplot(mpg) + aes(x="class", y="hwy") + geom_point())
# Out:
#     manufacturer   model  displ  year  cyl  ... drv cty  hwy  fl    class
# 0           audi      a4    1.8  1999    4  ...   f  18   29   p  compact
# 1           audi      a4    1.8  1999    4  ...   f  21   29   p  compact
# 2           audi      a4    2.0  2008    4  ...   f  20   31   p  compact
# 3           audi      a4    2.0  2008    4  ...   f  21   30   p  compact
# 4           audi      a4    2.8  1999    6  ...   f  16   26   p  compact
# ..           ...     ...    ...   ...  ...  ...  ..  ..  ...  ..      ...
# 229   volkswagen  passat    2.0  2008    4  ...   f  19   28   p  midsize
# 230   volkswagen  passat    2.0  2008    4  ...   f  21   29   p  midsize
# 231   volkswagen  passat    2.8  1999    6  ...   f  16   26   p  midsize
# 232   volkswagen  passat    2.8  1999    6  ...   f  18   26   p  midsize
# 233   volkswagen  passat    3.6  2008    6  ...   f  17   26   p  midsize
#
# [234 rows x 11 columns]
# <ggplot: (8769316504213)>

# %% [markdown]
# ## To Make a Bar Chart

# %%
print(ggplot(mpg) + aes(x="class") + geom_bar())
# Out:
# <ggplot: (8769316518761)>

# %% [markdown]
#  ## Staistical Transformations: Aggregate and Transform your Data
#
#  ### Create a histogram to display distributions of Lake Huron from 1875 to 1975

# %%
from plotnine.data import huron # dataset with the levels of Lake Huron 1875-1975

print(huron)

from plotnine import ggplot, aes, stat_bin, geom_bar # stat_bin() divides the level range into 20 equally sized bins. Then the number of measurements that falls into each bin is drawn using a bar plot.

ggplot(huron) + aes(x="level") + stat_bin(bins = 20) + geom_bar() # geom_histogram(bins=20) can also be used
# Out:
#     year   level  decade
# 0   1875  580.38    1870
# 1   1876  581.86    1870
# 2   1877  580.97    1870
# 3   1878  580.80    1870
# 4   1879  579.79    1870
# ..   ...     ...     ...
# 93  1968  578.52    1960
# 94  1969  579.74    1960
# 95  1970  579.31    1970
# 96  1971  579.89    1970
# 97  1972  579.96    1970
#
# [98 rows x 3 columns]
# <ggplot: (8769315083465)>

# %%
from plotnine import ggplot, aes, geom_boxplot

print(ggplot(huron) 
      + aes(x="factor(decade)", y="level")  
      + geom_boxplot()
     )
# Out:
# <ggplot: (8769315349737)>
